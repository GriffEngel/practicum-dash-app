# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('../Base_Dataset/OER cost savings spring 2023 (2).xlsx', sheet_name="Fall 2019")
df
# Out:
#           Course #                                        Course name  \
# 0   ECON:1100:0AAA                      Principles of Microeconomics
# 1   ECON:1100:0BBB                      Principles of Microeconomics
# 2   ECON:1100:0100                      Principles of Microeconomics
# 3   ACCT:2100:0EXW               Introduction to Financial Accounting
# 4    SOC:2170:0001                                   Research Methods
# 5    RCE:2081:0EXU             Making a Vocational-Educational Choice
# 6    RCE:2081:0EXV             Making a Vocational-Educational Choice
# 7    ECE:5995:0002  Contemp Topics in Elect & Computer Engineering...
# 8   CLSA:1000:0001  First-Year Seminar\nSubtitle: Introduction to ...
# 9     CS:3620:0001                                  Operating Systems
# 10   JMC:5400:0EXW                    Strategic Communication Writing
#
#     Instructor                                               OER   Enrollment  \
# 0        Stong           Principles of Microeconomics (OpenStax)          327
# 1        Stong           Principles of Microeconomics (OpenStax)          325
# 2        Stong           Principles of Microeconomics (OpenStax)           26
# 3         Moss                          Learn Accounting for Free          27
# 4      Bianchi  Principles Of Sociological Inquiry: Qualitativ...          22
# 5   Rechkemmer  Career Center Guide AND Career Exploration Han...          40
# 6   Rechkemmer  Career Center Guide AND Career Exploration Han...          40
# 7           Xu                                      Deep Learning          25
# 8       Storey  All course materials will be available online ...          23
# 9      Brummet  Operating Systems: 3 Easy Pieces by Arpaci-Dus...          54
# 10    Biderman  There will a free online open-source textbook ...          20
#
#     Fall Cost Savings
# 0                 NaN
# 1            38005.50
# 2             3040.44
# 3             3157.38
# 4             2572.68
# 5             4677.60
# 6             4677.60
# 7             2923.50
# 8             2689.62
# 9             6314.76
# 10            2338.80

# %%
df.replace(np.NaN, 38239.38, inplace=True)

# %%
df
# Out:
#           Course #                                        Course name  \
# 0   ECON:1100:0AAA                      Principles of Microeconomics
# 1   ECON:1100:0BBB                      Principles of Microeconomics
# 2   ECON:1100:0100                      Principles of Microeconomics
# 3   ACCT:2100:0EXW               Introduction to Financial Accounting
# 4    SOC:2170:0001                                   Research Methods
# 5    RCE:2081:0EXU             Making a Vocational-Educational Choice
# 6    RCE:2081:0EXV             Making a Vocational-Educational Choice
# 7    ECE:5995:0002  Contemp Topics in Elect & Computer Engineering...
# 8   CLSA:1000:0001  First-Year Seminar\nSubtitle: Introduction to ...
# 9     CS:3620:0001                                  Operating Systems
# 10   JMC:5400:0EXW                    Strategic Communication Writing
#
#     Instructor                                               OER   Enrollment  \
# 0        Stong           Principles of Microeconomics (OpenStax)          327
# 1        Stong           Principles of Microeconomics (OpenStax)          325
# 2        Stong           Principles of Microeconomics (OpenStax)           26
# 3         Moss                          Learn Accounting for Free          27
# 4      Bianchi  Principles Of Sociological Inquiry: Qualitativ...          22
# 5   Rechkemmer  Career Center Guide AND Career Exploration Han...          40
# 6   Rechkemmer  Career Center Guide AND Career Exploration Han...          40
# 7           Xu                                      Deep Learning          25
# 8       Storey  All course materials will be available online ...          23
# 9      Brummet  Operating Systems: 3 Easy Pieces by Arpaci-Dus...          54
# 10    Biderman  There will a free online open-source textbook ...          20
#
#     Fall Cost Savings
# 0            38239.38
# 1            38005.50
# 2             3040.44
# 3             3157.38
# 4             2572.68
# 5             4677.60
# 6             4677.60
# 7             2923.50
# 8             2689.62
# 9             6314.76
# 10            2338.80

# %%
phrases = [
    "EDTL",
    "COMM",
    "GEOG",
    "ITAL",
    "BIOS",
    "NURS",
    "MGMT",
    "SPAN",
    "RUSS",
    "SSW",
    "CSD",
    "MED",
    "KORE",
    "ARAB",
    "CS",
    "MATH",
    "MUSM",
    "POLI",
    "SWAH",
    "SLIS",
    "ANTH",
    "ECON",
    "PCOL",
    "ESL",
    "PHAR",
    "MICR",
    "MUSM",
    "ACCT",
    "SOC",
    "RCE",
    "ECE",
    "CLSA",
    "JMC",
]


assigned_value = [
    "Education",
    "Communication",
    "Geographical and Sustainablilty Sciences",
    "French and Italian",
    "Biostatistics",
    "College of Nursing",
    "Management and Entrepreneurship",
    "Spanish and Portuguese",
    "Russian",
    "School of Social Work",
    "Communication Sciences and Disorders",
    "Carver College of Medicine",
    "Asian & Slavic Languages and Literatures",
    "Arabic Language and Literature",
    "Computer Science",
    "Mathematics",
    "Museum Studies",
    "Political Science",
    "Swahili",
    "Library and Information Science",
    "Anthropology",
    "Economics",
    "Neuroscience and Pharamcology",
    "English as a Second Language Programs",
    "College of Pharmacy",
    "Microbiology and Immunology",
    "Museum Studies",
    "Accounting",
    "Sociology and Criminology",
    "Department of Counselor Education" ,
    "Electrical and Computer Engineering",
    "Classics",
    "School of Journalism and Mass Communication",
]


conditions = [df["Course #"].str.contains(phrase, na=False) for phrase in phrases]

default_value = "None"

df["Department"] = np.select(conditions, assigned_value, default_value)

# %%
df.drop("Fall Department", axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.drop("Fall Department", axis=1, inplace=True)
#
# File c:\Users\gneng\Datasets\env\Lib\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
#    5575         errors=errors,
#    5576     )
#
# File c:\Users\gneng\Datasets\env\Lib\site-packages\pandas\core\generic.py:4782, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4780 for axis, labels in axes.items():
#    4781     if labels is not None:
# -> 4782         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4784 if inplace:
#    4785     self._update_inplace(obj)
#
# File c:\Users\gneng\Datasets\env\Lib\site-packages\pandas\core\generic.py:4824, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4822         new_axis = axis.drop(labels, level=level, errors=errors)
#    4823     else:
# -> 4824         new_axis = axis.drop(labels, errors=errors)
#    4825     indexer = axis.get_indexer(new_axis)
#    4827 # Case for non-unique axis
#    4828 else:
#
# File c:\Users\gneng\Datasets\env\Lib\site-packages\pandas\core\indexes\base.py:7069, in Index.drop(self, labels, errors)
#    7067 if mask.any():
#    7068     if errors != "ignore":
# -> 7069         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7070     indexer = indexer[~mask]
#    7071 return self.delete(indexer)
#
# KeyError: "['Fall Department'] not found in axis"

# %%
df
# Out:
#           Course #                                        Course name  \
# 0   ECON:1100:0AAA                      Principles of Microeconomics
# 1   ECON:1100:0BBB                      Principles of Microeconomics
# 2   ECON:1100:0100                      Principles of Microeconomics
# 3   ACCT:2100:0EXW               Introduction to Financial Accounting
# 4    SOC:2170:0001                                   Research Methods
# 5    RCE:2081:0EXU             Making a Vocational-Educational Choice
# 6    RCE:2081:0EXV             Making a Vocational-Educational Choice
# 7    ECE:5995:0002  Contemp Topics in Elect & Computer Engineering...
# 8   CLSA:1000:0001  First-Year Seminar\nSubtitle: Introduction to ...
# 9     CS:3620:0001                                  Operating Systems
# 10   JMC:5400:0EXW                    Strategic Communication Writing
#
#     Instructor                                               OER   Enrollment  \
# 0        Stong           Principles of Microeconomics (OpenStax)          327
# 1        Stong           Principles of Microeconomics (OpenStax)          325
# 2        Stong           Principles of Microeconomics (OpenStax)           26
# 3         Moss                          Learn Accounting for Free          27
# 4      Bianchi  Principles Of Sociological Inquiry: Qualitativ...          22
# 5   Rechkemmer  Career Center Guide AND Career Exploration Han...          40
# 6   Rechkemmer  Career Center Guide AND Career Exploration Han...          40
# 7           Xu                                      Deep Learning          25
# 8       Storey  All course materials will be available online ...          23
# 9      Brummet  Operating Systems: 3 Easy Pieces by Arpaci-Dus...          54
# 10    Biderman  There will a free online open-source textbook ...          20
#
#     Fall Cost Savings                                   Department
# 0            38239.38                                    Economics
# 1            38005.50                                    Economics
# 2             3040.44                                    Economics
# 3             3157.38                                   Accounting
# 4             2572.68                    Sociology and Criminology
# 5             4677.60            Department of Counselor Education
# 6             4677.60            Department of Counselor Education
# 7             2923.50          Electrical and Computer Engineering
# 8             2689.62                                     Classics
# 9             6314.76                             Computer Science
# 10            2338.80  School of Journalism and Mass Communication

# %%
df = df.rename(columns={'Fall Cost Savings': 'Cost Savings ($)'})

# %%
df
# Out:
#           Course #                                        Course name  \
# 0   ECON:1100:0AAA                      Principles of Microeconomics
# 1   ECON:1100:0BBB                      Principles of Microeconomics
# 2   ECON:1100:0100                      Principles of Microeconomics
# 3   ACCT:2100:0EXW               Introduction to Financial Accounting
# 4    SOC:2170:0001                                   Research Methods
# 5    RCE:2081:0EXU             Making a Vocational-Educational Choice
# 6    RCE:2081:0EXV             Making a Vocational-Educational Choice
# 7    ECE:5995:0002  Contemp Topics in Elect & Computer Engineering...
# 8   CLSA:1000:0001  First-Year Seminar\nSubtitle: Introduction to ...
# 9     CS:3620:0001                                  Operating Systems
# 10   JMC:5400:0EXW                    Strategic Communication Writing
#
#     Instructor                                               OER   Enrollment  \
# 0        Stong           Principles of Microeconomics (OpenStax)          327
# 1        Stong           Principles of Microeconomics (OpenStax)          325
# 2        Stong           Principles of Microeconomics (OpenStax)           26
# 3         Moss                          Learn Accounting for Free          27
# 4      Bianchi  Principles Of Sociological Inquiry: Qualitativ...          22
# 5   Rechkemmer  Career Center Guide AND Career Exploration Han...          40
# 6   Rechkemmer  Career Center Guide AND Career Exploration Han...          40
# 7           Xu                                      Deep Learning          25
# 8       Storey  All course materials will be available online ...          23
# 9      Brummet  Operating Systems: 3 Easy Pieces by Arpaci-Dus...          54
# 10    Biderman  There will a free online open-source textbook ...          20
#
#     Cost Savings ($)                                   Department
# 0           38239.38                                    Economics
# 1           38005.50                                    Economics
# 2            3040.44                                    Economics
# 3            3157.38                                   Accounting
# 4            2572.68                    Sociology and Criminology
# 5            4677.60            Department of Counselor Education
# 6            4677.60            Department of Counselor Education
# 7            2923.50          Electrical and Computer Engineering
# 8            2689.62                                     Classics
# 9            6314.76                             Computer Science
# 10           2338.80  School of Journalism and Mass Communication

# %%
df.to_csv('1fall_2019.csv')
