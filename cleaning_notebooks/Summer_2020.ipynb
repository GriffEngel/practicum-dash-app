# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('../Base_Dataset/OER cost savings spring 2023 (2).xlsx', sheet_name="Summer 2020")
df
# Out:
#          Course #                               Course name Instructor  \
# 0  ACCT:2100:0EXW      Introduction to Financial Accounting       Moss
# 1       PHYS:1611                    Introductory Physics 1     Wetzel
# 2   SSW:3700:0EXW            Intro to Trauma and Resilience     Farley
# 3   SSW:3700:0EXT            Intro to Trauma and Resilience     Farley
# 4   SSW:3840:0EXV  Human Behavior in the Social Environment   Cummings
# 5   SSW:3840:0EXW  Human Behavior in the Social Environment   Cummings
#
#                                         OER   Enrollment  Cost Savings ($)
# 0                  Learn Accounting for Free        33.0               NaN
# 1                           OpenStax Physics         NaN              0.00
# 2  Trauma Informed Care document from SAMSHA        49.0           5730.06
# 3  Trauma Informed Care document from SAMSHA        41.0           4794.54
# 4   Human Behavior in the Social Environment        17.0           1987.98
# 5   Human Behavior in the Social Environment        24.0           2806.56

# %%
phrases = [
    "EDTL",
    "COMM",
    "GEOG",
    "ITAL",
    "BIOS",
    "NURS",
    "MGMT",
    "SPAN",
    "RUSS",
    "SSW",
    "CSD",
    "MED",
    "KORE",
    "ARAB",
    "CS",
    "MATH",
    "MUSM",
    "POLI",
    "SWAH",
    "SLIS",
    "ANTH",
    "ECON",
    "PCOL",
    "ESL",
    "PHAR",
    "MICR",
    "MUSM",
    "ACCT",
    "SOC",
    "RCE",
    "ECE",
    "CLSA",
    "JMC",
    "PHYS",
    
]


assigned_value = [
    "Education",
    "Communication",
    "Geographical and Sustainablilty Sciences",
    "French and Italian",
    "Biostatistics",
    "College of Nursing",
    "Management and Entrepreneurship",
    "Spanish and Portuguese",
    "Russian",
    "School of Social Work",
    "Communication Sciences and Disorders",
    "Carver College of Medicine",
    "Asian & Slavic Languages and Literatures",
    "Arabic Language and Literature",
    "Computer Science",
    "Mathematics",
    "Museum Studies",
    "Political Science",
    "Swahili",
    "Library and Information Science",
    "Anthropology",
    "Economics",
    "Neuroscience and Pharamcology",
    "English as a Second Language Programs",
    "College of Pharmacy",
    "Microbiology and Immunology",
    "Museum Studies",
    "Accounting",
    "Sociology and Criminology",
    "Department of Counselor Education" ,
    "Electrical and Computer Engineering",
    "Classics",
    "School of Journalism and Mass Communication",
    "Physics and Astronomy"
]


conditions = [df["Course #"].str.contains(phrase, na=False) for phrase in phrases]

default_value = "None"

df["Department"] = np.select(conditions, assigned_value, default_value)

# %%
df
# Out:
#          Course #                               Course name Instructor  \
# 0  ACCT:2100:0EXW      Introduction to Financial Accounting       Moss
# 1       PHYS:1611                    Introductory Physics 1     Wetzel
# 2   SSW:3700:0EXW            Intro to Trauma and Resilience     Farley
# 3   SSW:3700:0EXT            Intro to Trauma and Resilience     Farley
# 4   SSW:3840:0EXV  Human Behavior in the Social Environment   Cummings
# 5   SSW:3840:0EXW  Human Behavior in the Social Environment   Cummings
#
#                                         OER   Enrollment  Cost Savings ($)  \
# 0                  Learn Accounting for Free        33.0               NaN
# 1                           OpenStax Physics         NaN              0.00
# 2  Trauma Informed Care document from SAMSHA        49.0           5730.06
# 3  Trauma Informed Care document from SAMSHA        41.0           4794.54
# 4   Human Behavior in the Social Environment        17.0           1987.98
# 5   Human Behavior in the Social Environment        24.0           2806.56
#
#               Department
# 0             Accounting
# 1  Physics and Astronomy
# 2  School of Social Work
# 3  School of Social Work
# 4  School of Social Work
# 5  School of Social Work

# %%
df.fillna({"Cost Savings ($)": 3859.02}, inplace=True)

# %%
df
# Out:
#          Course #                               Course name Instructor  \
# 0  ACCT:2100:0EXW      Introduction to Financial Accounting       Moss
# 1       PHYS:1611                    Introductory Physics 1     Wetzel
# 2   SSW:3700:0EXW            Intro to Trauma and Resilience     Farley
# 3   SSW:3700:0EXT            Intro to Trauma and Resilience     Farley
# 4   SSW:3840:0EXV  Human Behavior in the Social Environment   Cummings
# 5   SSW:3840:0EXW  Human Behavior in the Social Environment   Cummings
#
#                                         OER   Enrollment  Cost Savings ($)  \
# 0                  Learn Accounting for Free        33.0           3859.02
# 1                           OpenStax Physics         NaN              0.00
# 2  Trauma Informed Care document from SAMSHA        49.0           5730.06
# 3  Trauma Informed Care document from SAMSHA        41.0           4794.54
# 4   Human Behavior in the Social Environment        17.0           1987.98
# 5   Human Behavior in the Social Environment        24.0           2806.56
#
#               Department
# 0             Accounting
# 1  Physics and Astronomy
# 2  School of Social Work
# 3  School of Social Work
# 4  School of Social Work
# 5  School of Social Work

# %%
df.fillna({"Enrollment": 0}, inplace=True)

# %%
df
# Out:
#          Course #                               Course name Instructor  \
# 0  ACCT:2100:0EXW      Introduction to Financial Accounting       Moss
# 1       PHYS:1611                    Introductory Physics 1     Wetzel
# 2   SSW:3700:0EXW            Intro to Trauma and Resilience     Farley
# 3   SSW:3700:0EXT            Intro to Trauma and Resilience     Farley
# 4   SSW:3840:0EXV  Human Behavior in the Social Environment   Cummings
# 5   SSW:3840:0EXW  Human Behavior in the Social Environment   Cummings
#
#                                         OER   Enrollment  Cost Savings ($)  \
# 0                  Learn Accounting for Free        33.0           3859.02
# 1                           OpenStax Physics         0.0              0.00
# 2  Trauma Informed Care document from SAMSHA        49.0           5730.06
# 3  Trauma Informed Care document from SAMSHA        41.0           4794.54
# 4   Human Behavior in the Social Environment        17.0           1987.98
# 5   Human Behavior in the Social Environment        24.0           2806.56
#
#               Department
# 0             Accounting
# 1  Physics and Astronomy
# 2  School of Social Work
# 3  School of Social Work
# 4  School of Social Work
# 5  School of Social Work

# %%
df.to_csv('summer_2020.csv')
